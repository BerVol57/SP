# %% [markdown]
# <img width="40%" style="margin:auto" src="https://kpi.ua/files/images-page/kpi-big-logo.png" >

# %% [markdown]
# <h1 align="center"><b>Курсова робота</b></h1>
# <h3 align="center"> <em><b>Аналіз даних за допомогою Python та бібліотеки Pandas</b></em> </h3>
#
# ---
#
# <p style="text-align:right"><b>Виконав:</b> </br> Студент групи ФІ-21 Беркута Володимир, НН ФТІ</p>

# %% [markdown]
# <h2 align="center">Частина №1</h2>
# <p>Мета: Вивчення основних принципів роботи та використання програмних
# компонентів Anaconda. Інсталяція. Дослідження можливостей IPython Notebook.</p>
# <h3 align="center">Вступ</h3>
# <p>Ipython Notebook — це середовище розробки, що дає можливості для
# інтерактивної та ітеративної розробки проектів, пов’язаних з Data Science.
# Notebook інтегрує код та результати його виконання в один файл разом з
# графіками, текстом, математичними виразами та іншими можливими видами
# представлення інформації.</br></br>
# JupyterLab - це новітнє інтерактивне веб-середовище для розробки блокнотів, коду та даних. Його гнучкий інтерфейс дозволяє користувачам налаштовувати та організовувати робочі процеси в науці про дані, наукових обчисленнях, комп'ютерній журналістиці та машинному навчанні. Модульна конструкція дозволяє розширювати та збагачувати функціональність.</br></br>
# Блокнот (notebook) представляє код і результат його виведення в єдиному документі, який об’єднує візуалізацію, розмічений текст, математичні рівняння та інші мультимедійні дані. Цей інтуїтивно зрозумілий робочий процес сприяє ітеративній і швидкій розробці, що робить ноутбуки все більш популярним вибором для подання даних і їх аналізу. Notebook інтегрує код та результати його виконання в один файл разом з графіками, текстом, математичними виразами та іншими можливими видами представлення інформації.</p>
# <h3 align="center">Підготовка до роботи</h3>
# <ol>
#     <li>Для початку варто завантажити <a href="https://www.anaconda.com/download">Anaconda Distribution</a></li>
#     <li>Після завантаження запускаємо <b>Anaconda Poweshell Prompt</b></li>
#     <li>За допомогою команди <code>cd Папка1\папка2</code> вибираємо необхідну директорію, а командою <code>[потрібний диск]:</code> змніюємо диск</li>
#     <li>Далі створюємо віртуальне середовище командою <code>conda --prefix=[Назва вірутального середовища] python=3.11.5</code></li>
#     <li><code>conda activate</code> - активуємо середовище</li>
#     <li>Інсталюємо JupyterLab <code>conda install jupyterlab</code></li>
#     <li>Командою <code>jupyter lab</code> запускаємо JupyterLab</li>
# </ol>
# <h3 align="center">Можливості Jupyter Notebook</h3>
# <ul>
#     <li>Редагувати Python код в браузері, з підсвічуванням синтаксису, автовідступами і автодоповненням</li>
#     <li>Запускати код в браузері</li>
#     <li>Відображати результати обчислень з медіа представленням(схеми, графіки)</li>
#     <li>Працювати з мовою розмітки Markdown і LaTeX</li>
# </ul>

# %% [markdown]
# Приклад роботи з LaTeX
# $$\frac{1}{\sigma\sqrt{2\pi}}\exp\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)$$

# %% [markdown]
# <h2 align="center">Частина №2</h2>
# <p>Мета: Отримати досвід використання основних засобів аналізу та візуалізації даних у середовищі IPython Notebook на модельних наборах даних.</br></br>
# В роботі використовується публічний набір даних <a href="https://www.kaggle.com/datasets/neuromusic/avocado-prices"><em><b>Avocado Prices</b></em></a>.</p>

# %% [markdown]
# #### Завдання №1
# Дане завдання з частини №2 було виконане під час підготовки до роботи

# %% [markdown]
# ##### Імпортуємо необхідні бібліотеки

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings

sns.set_style("darkgrid")

warnings.filterwarnings('ignore')
print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# #### Завдання №2
# Відкриваємо dataset та виводимо перших 5 рядків

# %%
df = pd.read_csv("dataset/avocado.csv", index_col="Unnamed: 0")
df = df.sort_values(by=['Date'])
df.head()
# Out:
#           Date  AveragePrice  Total Volume     4046      4225     4770  \
# 51  2015-01-04          1.75      27365.89  9307.34   3844.81   615.28
# 51  2015-01-04          1.49      17723.17  1189.35  15628.27     0.00
# 51  2015-01-04          1.68       2896.72   161.68    206.96     0.00
# 51  2015-01-04          1.52      54956.80  3013.04  35456.88  1561.70
# 51  2015-01-04          1.64       1505.12     1.27   1129.50     0.00
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 51    13598.46    13061.10      537.36          0.0       organic  2015
# 51      905.55      905.55        0.00          0.0       organic  2015
# 51     2528.08     2528.08        0.00          0.0       organic  2015
# 51    14925.18    11264.80     3660.38          0.0  conventional  2015
# 51      374.35      186.67      187.68          0.0       organic  2015
#
#                 region
# 51           Southeast
# 51             Chicago
# 51  HarrisburgScranton
# 51          Pittsburgh
# 51               Boise

# %% [markdown]
# #### Завдання №3
# Перевіряємо на наявність порожніх значень

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Завдання №4
# Представлення набору даних у матричному вигляді. Відображення 10 елементів для 4-ох ознак Виділення зеленим кольором максимальні елементи в таблиці, а червоним мінімальні для цих 10-ти елементів.

# %%
df_matrix_foramt = df.pivot(columns=["region", "type"], index="Date", values="AveragePrice").head(10).sort_values(by=["region"], axis=1)
display(df_matrix_foramt.style.highlight_max(axis=0, props="background-color:green").\
format('{:.2f}').\
highlight_min(axis=0, props="background-color:red").\
set_table_styles([{'selector': 'th.col_heading', 'props': 'text-align: center;'}], overwrite=False))
# Out:
# <style type="text/css">
# #T_522cb th.col_heading {
#   text-align: center;
# }
# #T_522cb_row0_col8, #T_522cb_row0_col17, #T_522cb_row0_col20, #T_522cb_row0_col28, #T_522cb_row0_col35, #T_522cb_row0_col39, #T_522cb_row0_col42, #T_522cb_row0_col43, #T_522cb_row0_col46, #T_522cb_row0_col56, #T_522cb_row0_col59, #T_522cb_row0_col66, #T_522cb_row0_col87, #T_522cb_row0_col94, #T_522cb_row1_col12, #T_522cb_row1_col45, #T_522cb_row1_col65, #T_522cb_row1_col82, #T_522cb_row1_col83, #T_522cb_row2_col55, #T_522cb_row2_col69, #T_522cb_row2_col81, #T_522cb_row2_col91, #T_522cb_row2_col104, #T_522cb_row4_col1, #T_522cb_row4_col3, #T_522cb_row4_col4, #T_522cb_row4_col5, #T_522cb_row4_col6, #T_522cb_row4_col11, #T_522cb_row4_col15, #T_522cb_row4_col16, #T_522cb_row4_col18, #T_522cb_row4_col21, #T_522cb_row4_col22, #T_522cb_row4_col24, #T_522cb_row4_col26, #T_522cb_row4_col27, #T_522cb_row4_col29, #T_522cb_row4_col30, #T_522cb_row4_col31, #T_522cb_row4_col34, #T_522cb_row4_col36, #T_522cb_row4_col38, #T_522cb_row4_col41, #T_522cb_row4_col44, #T_522cb_row4_col47, #T_522cb_row4_col49, #T_522cb_row4_col50, #T_522cb_row4_col52, #T_522cb_row4_col54, #T_522cb_row4_col58, #T_522cb_row4_col62, #T_522cb_row4_col67, #T_522cb_row4_col70, #T_522cb_row4_col73, #T_522cb_row4_col74, #T_522cb_row4_col77, #T_522cb_row4_col78, #T_522cb_row4_col84, #T_522cb_row4_col85, #T_522cb_row4_col87, #T_522cb_row4_col89, #T_522cb_row4_col90, #T_522cb_row4_col93, #T_522cb_row4_col95, #T_522cb_row4_col101, #T_522cb_row4_col102, #T_522cb_row4_col103, #T_522cb_row4_col105, #T_522cb_row4_col107, #T_522cb_row5_col0, #T_522cb_row5_col1, #T_522cb_row5_col7, #T_522cb_row5_col23, #T_522cb_row5_col33, #T_522cb_row5_col37, #T_522cb_row5_col40, #T_522cb_row5_col52, #T_522cb_row5_col59, #T_522cb_row5_col61, #T_522cb_row5_col64, #T_522cb_row5_col71, #T_522cb_row5_col80, #T_522cb_row5_col86, #T_522cb_row5_col96, #T_522cb_row5_col98, #T_522cb_row6_col53, #T_522cb_row6_col75, #T_522cb_row7_col9, #T_522cb_row7_col10, #T_522cb_row7_col51, #T_522cb_row7_col60, #T_522cb_row7_col99, #T_522cb_row8_col1, #T_522cb_row8_col2, #T_522cb_row8_col13, #T_522cb_row8_col60, #T_522cb_row8_col63, #T_522cb_row8_col72, #T_522cb_row8_col76, #T_522cb_row8_col79, #T_522cb_row8_col88, #T_522cb_row8_col92, #T_522cb_row8_col100, #T_522cb_row9_col2, #T_522cb_row9_col14, #T_522cb_row9_col19, #T_522cb_row9_col25, #T_522cb_row9_col32, #T_522cb_row9_col48, #T_522cb_row9_col57, #T_522cb_row9_col65, #T_522cb_row9_col68, #T_522cb_row9_col97, #T_522cb_row9_col106 {
#   background-color: red;
# }
# #T_522cb_row0_col10, #T_522cb_row1_col1, #T_522cb_row1_col3, #T_522cb_row1_col6, #T_522cb_row1_col11, #T_522cb_row1_col14, #T_522cb_row1_col15, #T_522cb_row1_col33, #T_522cb_row1_col40, #T_522cb_row1_col46, #T_522cb_row1_col53, #T_522cb_row1_col63, #T_522cb_row1_col68, #T_522cb_row1_col69, #T_522cb_row1_col74, #T_522cb_row1_col76, #T_522cb_row1_col88, #T_522cb_row1_col92, #T_522cb_row1_col98, #T_522cb_row1_col100, #T_522cb_row1_col107, #T_522cb_row2_col0, #T_522cb_row2_col3, #T_522cb_row2_col8, #T_522cb_row2_col19, #T_522cb_row2_col30, #T_522cb_row2_col32, #T_522cb_row2_col39, #T_522cb_row2_col41, #T_522cb_row2_col46, #T_522cb_row2_col49, #T_522cb_row2_col51, #T_522cb_row2_col52, #T_522cb_row2_col56, #T_522cb_row2_col58, #T_522cb_row2_col59, #T_522cb_row2_col62, #T_522cb_row2_col64, #T_522cb_row2_col65, #T_522cb_row2_col71, #T_522cb_row2_col78, #T_522cb_row2_col80, #T_522cb_row2_col89, #T_522cb_row2_col93, #T_522cb_row2_col99, #T_522cb_row2_col101, #T_522cb_row3_col2, #T_522cb_row3_col7, #T_522cb_row3_col9, #T_522cb_row3_col13, #T_522cb_row3_col14, #T_522cb_row3_col16, #T_522cb_row3_col17, #T_522cb_row3_col27, #T_522cb_row3_col28, #T_522cb_row3_col44, #T_522cb_row3_col60, #T_522cb_row3_col71, #T_522cb_row3_col75, #T_522cb_row3_col82, #T_522cb_row3_col94, #T_522cb_row3_col97, #T_522cb_row3_col103, #T_522cb_row4_col79, #T_522cb_row4_col97, #T_522cb_row4_col106, #T_522cb_row6_col12, #T_522cb_row6_col18, #T_522cb_row6_col22, #T_522cb_row6_col24, #T_522cb_row6_col25, #T_522cb_row6_col42, #T_522cb_row6_col45, #T_522cb_row6_col66, #T_522cb_row6_col72, #T_522cb_row6_col73, #T_522cb_row6_col81, #T_522cb_row6_col83, #T_522cb_row6_col84, #T_522cb_row6_col87, #T_522cb_row6_col95, #T_522cb_row6_col102, #T_522cb_row6_col104, #T_522cb_row7_col8, #T_522cb_row7_col17, #T_522cb_row7_col21, #T_522cb_row7_col29, #T_522cb_row7_col31, #T_522cb_row7_col34, #T_522cb_row7_col38, #T_522cb_row7_col42, #T_522cb_row7_col43, #T_522cb_row7_col48, #T_522cb_row7_col57, #T_522cb_row7_col61, #T_522cb_row7_col84, #T_522cb_row8_col5, #T_522cb_row8_col20, #T_522cb_row8_col23, #T_522cb_row8_col26, #T_522cb_row8_col37, #T_522cb_row8_col54, #T_522cb_row8_col86, #T_522cb_row8_col90, #T_522cb_row9_col4, #T_522cb_row9_col35, #T_522cb_row9_col36, #T_522cb_row9_col47, #T_522cb_row9_col49, #T_522cb_row9_col50, #T_522cb_row9_col52, #T_522cb_row9_col55, #T_522cb_row9_col64, #T_522cb_row9_col67, #T_522cb_row9_col70, #T_522cb_row9_col74, #T_522cb_row9_col77, #T_522cb_row9_col85, #T_522cb_row9_col91, #T_522cb_row9_col96, #T_522cb_row9_col105 {
#   background-color: green;
# }
# </style>
# <table id="T_522cb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th id="T_522cb_level0_col0" class="col_heading level0 col0" colspan="2">Albany</th>
#       <th id="T_522cb_level0_col2" class="col_heading level0 col2" colspan="2">Atlanta</th>
#       <th id="T_522cb_level0_col4" class="col_heading level0 col4" colspan="2">BaltimoreWashington</th>
#       <th id="T_522cb_level0_col6" class="col_heading level0 col6" colspan="2">Boise</th>
#       <th id="T_522cb_level0_col8" class="col_heading level0 col8" colspan="2">Boston</th>
#       <th id="T_522cb_level0_col10" class="col_heading level0 col10" colspan="2">BuffaloRochester</th>
#       <th id="T_522cb_level0_col12" class="col_heading level0 col12" colspan="2">California</th>
#       <th id="T_522cb_level0_col14" class="col_heading level0 col14" colspan="2">Charlotte</th>
#       <th id="T_522cb_level0_col16" class="col_heading level0 col16" colspan="2">Chicago</th>
#       <th id="T_522cb_level0_col18" class="col_heading level0 col18" colspan="2">CincinnatiDayton</th>
#       <th id="T_522cb_level0_col20" class="col_heading level0 col20" colspan="2">Columbus</th>
#       <th id="T_522cb_level0_col22" class="col_heading level0 col22" colspan="2">DallasFtWorth</th>
#       <th id="T_522cb_level0_col24" class="col_heading level0 col24" colspan="2">Denver</th>
#       <th id="T_522cb_level0_col26" class="col_heading level0 col26" colspan="2">Detroit</th>
#       <th id="T_522cb_level0_col28" class="col_heading level0 col28" colspan="2">GrandRapids</th>
#       <th id="T_522cb_level0_col30" class="col_heading level0 col30" colspan="2">GreatLakes</th>
#       <th id="T_522cb_level0_col32" class="col_heading level0 col32" colspan="2">HarrisburgScranton</th>
#       <th id="T_522cb_level0_col34" class="col_heading level0 col34" colspan="2">HartfordSpringfield</th>
#       <th id="T_522cb_level0_col36" class="col_heading level0 col36" colspan="2">Houston</th>
#       <th id="T_522cb_level0_col38" class="col_heading level0 col38" colspan="2">Indianapolis</th>
#       <th id="T_522cb_level0_col40" class="col_heading level0 col40" colspan="2">Jacksonville</th>
#       <th id="T_522cb_level0_col42" class="col_heading level0 col42" colspan="2">LasVegas</th>
#       <th id="T_522cb_level0_col44" class="col_heading level0 col44" colspan="2">LosAngeles</th>
#       <th id="T_522cb_level0_col46" class="col_heading level0 col46" colspan="2">Louisville</th>
#       <th id="T_522cb_level0_col48" class="col_heading level0 col48" colspan="2">MiamiFtLauderdale</th>
#       <th id="T_522cb_level0_col50" class="col_heading level0 col50" colspan="2">Midsouth</th>
#       <th id="T_522cb_level0_col52" class="col_heading level0 col52" colspan="2">Nashville</th>
#       <th id="T_522cb_level0_col54" class="col_heading level0 col54" colspan="2">NewOrleansMobile</th>
#       <th id="T_522cb_level0_col56" class="col_heading level0 col56" colsp

# %% [markdown]
# ##### Математичне сподівання та дисперсія
# Математичне сподівання обраховується за наступною формулою:
# $$\overline{X} = \frac{1}{n}\sum_{i=1}^{n} X_i$$
# А дисперсія за цією:
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^{n}{X_i^2} - \overline{X}^2}$$

# %%
X_ = lambda x: x.sum()/len(x)
disp = lambda x: np.sqrt(sum(x**2)/len(x) - X_(x)**2)
print("Порівння обчисленого матемитичного сподівання за допомгою функції Pandas та формулою:",
      abs(X_(df["AveragePrice"])-df["AveragePrice"].mean()))
print("Порівння обчисленої дисперсії за допомгою функції Pandas та формулою:",
      abs(disp(df["AveragePrice"])-df["AveragePrice"].std()))
# Out:
# Порівння обчисленого матемитичного сподівання за допомгою функції Pandas та формулою: 0.0
# Порівння обчисленої дисперсії за допомгою функції Pandas та формулою: 1.1032990031523138e-05

# %% [markdown]
# ##### Стандартизування даних

# %%
def standartization(df):
    dataframe = df.copy()
    
    df_for_stand_org = dataframe[dataframe["type"]=="organic"].select_dtypes(include='float64')
    df_for_stand_org  = ( df_for_stand_org - df_for_stand_org.mean() )/ df_for_stand_org.std()
    
    df_for_stand_conv = dataframe[dataframe["type"]=="conventional"].select_dtypes(include='float64')
    df_for_stand_conv  = ( df_for_stand_conv - df_for_stand_conv.mean() )/ df_for_stand_conv.std()
    
    standartization_df = dataframe
    
    standartization_df.loc[standartization_df["type"]=="organic", list(df_for_stand_org.columns)] = df_for_stand_org
    standartization_df.loc[standartization_df["type"]=="conventional", list(df_for_stand_org.columns)] = df_for_stand_conv
    return standartization_df


standartization(df[df["region"]=="TotalUS"])
# Out:
#           Date  AveragePrice  Total Volume      4046      4225      4770  \
# 51  2015-01-04     -0.815603     -0.394038  0.140141  0.850200 -0.173310
# 51  2015-01-04     -0.424313     -1.172483  1.595150 -1.187734 -0.265342
# 50  2015-01-11     -0.621586     -0.985303  2.303270 -0.612993 -0.403453
# 50  2015-01-11     -0.471011     -0.763554 -0.188716  0.220000 -0.121089
# 49  2015-01-18     -0.621586     -0.841192  1.990425  0.045691 -0.354799
# ..         ...           ...           ...       ...       ...       ...
# 2   2018-03-11     -0.011554      1.097493  0.841265 -0.362563 -0.490414
# 1   2018-03-18     -0.029766      2.341421  0.420903  1.770658 -1.115006
# 1   2018-03-18     -0.241283      1.250598  0.686744 -0.234344 -0.634891
# 0   2018-03-25      0.019552      1.958467 -0.514858  0.447878 -1.108654
# 0   2018-03-25     -0.356147      1.581342  0.858150  0.216166 -0.371432
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 51   -1.488867   -1.545307   -1.191652    -1.019055  conventional  2015
# 51   -1.241281   -1.058389   -1.129569    -0.344028       organic  2015
# 50   -1.330357   -1.094194   -1.311193    -0.344028       organic  2015
# 50   -1.483014   -1.455734   -1.371772    -1.046200  conventional  2015
# 49   -1.297391   -1.115937   -1.156335    -0.344028       organic  2015
# ..         ...         ...         ...          ...           ...   ...
# 2     1.810295    1.987787    1.189334     1.370344  conventional  2018
# 1     1.980740    2.086131    0.806406     2.214936       organic  2018
# 1     2.152272    2.132585    1.962947     1.361635  conventional  2018
# 0     2.106790    2.370955    0.477257     1.828062       organic  2018
# 0     2.286204    2.507059    1.510768     1.718248  conventional  2018
#
#      region
# 51  TotalUS
# 51  TotalUS
# 50  TotalUS
# 50  TotalUS
# 49  TotalUS
# ..      ...
# 2   TotalUS
# 1   TotalUS
# 1   TotalUS
# 0   TotalUS
# 0   TotalUS
#
# [338 rows x 13 columns]

# %% [markdown]
# #### Завдання №5
# Візуалізація даних

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 18))

sns.lineplot(
    ax = axes[0, 0], data = standartization(df[df["region"]=="TotalUS"]),
    x = "AveragePrice", y = "Total Volume", hue = "type",
    marker = "o"
)
axes[0, 0].set_title("(Lineplot) ")

sns.barplot(
    ax = axes[0, 1], data = df[df["region"].isin(list(df["region"].head()))], x = "region", y = "Total Volume",
    hue = "type"
)
axes[0, 1].set_title("(Barplot) ")

sns.heatmap(
    ax = axes[1, 0], data = df.loc[(df["type"]=="organic")&(df["region"].isin(list(set(list(df["region"])))[:10]))&(df["Date"].isin(sorted(list(set(list(df["Date"]))))[:10]))].pivot(index="region", columns="Date", values="AveragePrice"),
    annot = True
)
axes[1, 0].set_title("(Heatmap) ")

sns.histplot(
    ax = axes[1, 1], data = standartization(df),
    x = "AveragePrice", stat = "count", hue = "type"
)
axes[1, 1].set_title("(Histplot) ")
display()

# %% [markdown]
# #### Завдання №6
# Збудувати лінійний графік з 4-ма лініями, які взяті з ознак та додати annotate для середнього
# значення кожної лінії.

# %%
df_for_4_lines = df.loc[df["region"].isin(["TotalUS", "NewYork"])][["Date", "AveragePrice", "type", "region"]]

plt.figure(figsize=(18,6))

g = sns.lineplot(data=df_for_4_lines, 
                 x="Date", 
                 y="AveragePrice", 
                 hue="type", 
                 palette=["orange", "c"], 
                 style="region",
                 ci=None)
g.set_xticks(df_for_4_lines.loc[df_for_4_lines.index.values==51]["Date"].values)

for i in set(df_for_4_lines["type"].values):
    for j in set(df_for_4_lines["region"].values):
        
        line_color = sns.color_palette("bright")[0] if i=="organic" else sns.color_palette("dark")[1]
        line_stl = "-." if j=="TotalUS" else ":"
        
        y_mean = df_for_4_lines[(df_for_4_lines["type"]==i)&(df_for_4_lines["region"]==j)]["AveragePrice"].mean()
        
        g.axhline(y_mean, ls=line_stl, color=line_color)
        g.text(0, y_mean+.05, f"mean:{round(y_mean, 3)}", color=line_color)
        pass

# %% [markdown]
# Візуалізації багатовимірних даних з кількістю ознак
# більше двох обов’язково необхідно за допомогою subplot збудувати більше 9 графіків за
# допомогою комбінування різних ознак.

# %%
featers = df.drop(["Date", "type", "year", "region"], axis=1).columns.values

plot_9_df = df[(df["region"]=="TotalUS")&(df["type"]=="conventional")]
fig, axes = plt.subplots(featers.shape[0], featers.shape[0], figsize=(18, 18))#, sharex="col", sharey="row")

for i in range(featers.shape[0]):
    for j in range(featers.shape[0]):
        if i==j:
            sns.histplot(data=plot_9_df, 
                         ax=axes[i, i], 
                         x=featers[i], 
                         color="orange", 
                         bins=30)
            
        else: 
            sns.scatterplot(data=plot_9_df,
                            ax=axes[i, j],
                            x=featers[j], 
                            y=featers[i])

# %% [markdown]
# #### Завдання №7
# Вирахувати коефіцієнт пірсона для кожної пари ознак.
# Взяти третю ознаку за вісь X та збудувати relplot для двох ознак, що мають найбільшу
# кореляцію за допомогою бібліотеки seaborn.

# %%
pre_df_corr = df.drop(["year"], axis=1)
pre_df_corr = pre_df_corr.loc[(pre_df_corr["region"]=="TotalUS")&(pre_df_corr["type"]=="organic")]
df_corr = pre_df_corr.drop(["Date", "region", "type"], axis=1).corr(method="pearson")
val = df_corr.values
val = val.reshape(val.size)
max_value = sorted(set(val))[:-1:][:-2:-1]

def highlights_2_max(s):
    return "background-color: yellow;" if (s in max_value) else None

df_corr.style.map(highlights_2_max)
# Out:
# <style type="text/css">
# #T_25a92_row5_col6, #T_25a92_row6_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_25a92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25a92_level0_col0" class="col_heading level0 col0" >AveragePrice</th>
#       <th id="T_25a92_level0_col1" class="col_heading level0 col1" >Total Volume</th>
#       <th id="T_25a92_level0_col2" class="col_heading level0 col2" >4046</th>
#       <th id="T_25a92_level0_col3" class="col_heading level0 col3" >4225</th>
#       <th id="T_25a92_level0_col4" class="col_heading level0 col4" >4770</th>
#       <th id="T_25a92_level0_col5" class="col_heading level0 col5" >Total Bags</th>
#       <th id="T_25a92_level0_col6" class="col_heading level0 col6" >Small Bags</th>
#       <th id="T_25a92_level0_col7" class="col_heading level0 col7" >Large Bags</th>
#       <th id="T_25a92_level0_col8" class="col_heading level0 col8" >XLarge Bags</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25a92_level0_row0" class="row_heading level0 row0" >AveragePrice</th>
#       <td id="T_25a92_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_25a92_row0_col1" class="data row0 col1" >0.024432</td>
#       <td id="T_25a92_row0_col2" class="data row0 col2" >-0.306326</td>
#       <td id="T_25a92_row0_col3" class="data row0 col3" >-0.321156</td>
#       <td id="T_25a92_row0_col4" class="data row0 col4" >-0.393561</td>
#       <td id="T_25a92_row0_col5" class="data row0 col5" >0.178775</td>
#       <td id="T_25a92_row0_col6" class="data row0 col6" >0.318327</td>
#       <td id="T_25a92_row0_col7" class="data row0 col7" >-0.252887</td>
#       <td id="T_25a92_row0_col8" class="data row0 col8" >0.187186</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row1" class="row_heading level0 row1" >Total Volume</th>
#       <td id="T_25a92_row1_col0" class="data row1 col0" >0.024432</td>
#       <td id="T_25a92_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_25a92_row1_col2" class="data row1 col2" >-0.032949</td>
#       <td id="T_25a92_row1_col3" class="data row1 col3" >0.585107</td>
#       <td id="T_25a92_row1_col4" class="data row1 col4" >-0.215274</td>
#       <td id="T_25a92_row1_col5" class="data row1 col5" >0.930180</td>
#       <td id="T_25a92_row1_col6" class="data row1 col6" >0.864594</td>
#       <td id="T_25a92_row1_col7" class="data row1 col7" >0.667414</td>
#       <td id="T_25a92_row1_col8" class="data row1 col8" >0.347537</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row2" class="row_heading level0 row2" >4046</th>
#       <td id="T_25a92_row2_col0" class="data row2 col0" >-0.306326</td>
#       <td id="T_25a92_row2_col1" class="data row2 col1" >-0.032949</td>
#       <td id="T_25a92_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_25a92_row2_col3" class="data row2 col3" >0.397019</td>
#       <td id="T_25a92_row2_col4" class="data row2 col4" >0.215481</td>
#       <td id="T_25a92_row2_col5" class="data row2 col5" >-0.338641</td>
#       <td id="T_25a92_row2_col6" class="data row2 col6" >-0.328086</td>
#       <td id="T_25a92_row2_col7" class="data row2 col7" >-0.209532</td>
#       <td id="T_25a92_row2_col8" class="data row2 col8" >-0.238402</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row3" class="row_heading level0 row3" >4225</th>
#       <td id="T_25a92_row3_col0" class="data row3 col0" >-0.321156</td>
#       <td id="T_25a92_row3_col1" class="data row3 col1" >0.585107</td>
#       <td id="T_25a92_row3_col2" class="data row3 col2" >0.397019</td>
#       <td id="T_25a92_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_25a92_row3_col4" class="data row3 col4" >0.314611</td>
#       <td id="T_25a92_row3_col5" class="data row3 col5" >0.277303</td>
#       <td id="T_25a92_row3_col6" class="data row3 col6" >0.183909</td>
#       <td id="T_25a92_row3_col7" class="data row3 col7" >0.384068</td>
#       <td id="T_25a92_row3_col8" class="data row3 col8" >-0.122565</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row4" class="row_heading level0 row4" >4770</th>
#       <td id="T_25a92_row4_col0" class="data row4 col0" >-0.393561</td>
#       <td id="T_25a92_row4_col1" class="data row4 col1" >-0.215274</td>
#       <td id="T_25a92_row4_col2" class="data row4 col2" >0.215481</td>
#       <td id="T_25a92_row4_col3" class="data row4 col3" >0.314611</td>
#       <td id="T_25a92_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_25a92_row4_col5" class="data row4 col5" >-0.374818</td>
#       <td id="T_25a92_row4_col6" class="data row4 col6" >-0.443166</td>
#       <td id="T_25a92_row4_col7" class="data row4 col7" >-0.031409</td>
#       <td id="T_25a92_row4_col8" class="data row4 col8" >-0.363915</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row5" class="row_heading level0 row5" >Total Bags</th>
#       <td id="T_25a92_row5_col0" class="data row5 col0" >0.178775</td>
#       <td id="T_25a92_row5_col1" class="data row5 col1" >0.930180</td>
#       <td id="T_25a92_row5_col2" class="data row5 col2" >-0.338641</td>
#       <td id="T_25a92_row5_col3" class="data row5 col3" >0.277303</td>
#       <td id="T_25a92_row5_col4" class="data row5 col4" >-0.374818</td>
#       <td id="T_25a92_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_25a92_row5_col6" class="data row5 col6" >0.953643</td>
#       <td id="T_25a92_row5_col7" class="data row5 col7" >0.656958</td>
#       <td id="T_25a92_row5_col8" class="data row5 col8" >0.460310</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row6" class="row_heading level0 row6" >Small Bags</th>
#       <td id="T_25a92_row6_col0" class="data row6 col0" >0.318327</td>
#       <td id="T_25a92_row6_col1" class="data row6 col1" >0.864594</td>
#       <td id="T_25a92_row6_col2" class="data row6 col2" >-0.328086</td>
#       <td id="T_25a92_row6_col3" class="data row6 col3" >0.183909</td>
#       <td id="T_25a92_row6_col4" class="data row6 col4" >-0.443166</td>
#       <td id="T_25a92_row6_col5" class="data row6 col5" >0.953643</td>
#       <td id="T_25a92_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_25a92_row6_col7" class="data row6 col7" >0.399616</td>
#       <td id="T_25a92_row6_col8" class="data row6 col8" >0.534859</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row7" class="row_heading level0 row7" >Large Bags</th>
#       <td id="T_25a92_row7_col0" class="data row7 col0" >-0.252887</td>
#       <td id="T_25a92_row7_col1" class="data row7 col1" >0.667414</td>
#       <td id="T_25a92_row7_col2" class="data row7 col2" >-0.209532</td>
#       <td id="T_25a92_row7_col3" class="data row7 col3" >0.384068</td>
#       <td id="T_25a92_row7_col4" class="data row7 col4" >-0.031409</td>
#       <td id="T_25a92_row7_col5" class="data row7 col5" >0.656958</td>
#       <td id="T_25a92_row7_col6" class="data row7 col6" >0.399616</td>
#       <td id="T_25a92_row7_col7" class="data row7 col7" >1.000000</td>
#       <td id="T_25a92_row7_col8" class="data row7 col8" >0.061685</td>
#     </tr>
#     <tr>
#       <th id="T_25a92_level0_row8" class="row_heading level0 row8" >XLarge Bags</th>
#       <td id="T_25a92_row8_col0" class="data row8 col0" >0.187186</td>
#       <td id="T_25a92_row8_col1" class="data row8 col1" >0.347537</td>
#       <td id="T_25a92_row8_col2" class="data row8 col2" >-0.238402</td>
#       <td id="T_25a92_row8_col3" class="data row8 col3" >-0.122565</td>
#       <td id="T_25a92_row8_col4" class="data row8 col4" >-0.363915</td>
#       <td id="T_25a92_row8_col5" class="data row8 col5" >0.460310</td>
#       <td id="T_25a92_row8_col6" class="data row8 col6" >0.534859</td>
#       <td id="T_25a92_row8_col7" class="data row8 col7" >0.061685</td>
#       <td id="T_25a92_row8_col8" class="data row8 col8" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Отже маємо найбільше значення для таких ознак "Small Bags" та "Total Bags".

# %%
sns.relplot(data=df.loc[(df["region"]=="TotalUS")&(df["type"]=="organic")], 
            x="Total Bags", 
            y="Small Bags", 
            height=12, 
            aspect=2, s=100,
            kind="scatter")
display()

# %% [markdown]
# #### Завдання №8
# Оскільки цей набір даних не має порожніх значень, одже процедури заповнення порожніх данних не було

# %% [markdown]
# #### Завдання №9
# Видалити також випадкові значення з ознак що мають найбільшу кореляцію у кількості 10%
# для обох. Підрахувати кореляцію. Збудувати multipple scatterplot за допомогою FacetGrid
# для цих оновлених ознак використовуючи бібліотеку seaborn взявши третю ознаку за вісь x.

# %%
df_with_10 = pre_df_corr.drop(["region", "type"], axis=1)
df_without_10 = df_with_10.iloc[np.random.choice(df_with_10.shape[0], round(df_with_10.shape[0]*.9))]

fig, axes = plt.subplots(1, 2, figsize=(18, 8))

sns.heatmap(data=df_with_10.drop(["Date"], axis=1).corr(method="pearson"), ax=axes[0], annot=True)
sns.heatmap(data=df_without_10.drop(["Date"], axis=1).corr(method="pearson"), ax=axes[1], annot=True)
display()

# %% [markdown]
# Візьмемо за третю ознаку "Date"

# %%
df_for_random_drop = df.loc[(df["region"]=="Atlanta")&(df["type"]=="organic")]
df_without_10 = df_without_10.sort_values(by="Date")
check = np.sqrt(df_without_10.columns.shape[0]-1)

if check == int(check):
    check = int(check)
else: 
    check = int(check)+1


g = sns.FacetGrid(pd.DataFrame(df_without_10.drop("Date", axis=1).columns), 
                  col=0, col_wrap=check, sharey=False, height=4, aspect=1)

for ax, yvar in zip(g.axes, df_without_10.drop("Date", axis=1).columns.values):
    sns.scatterplot(data=df_without_10, x="Date", y=yvar, ax=ax)
    ax.set_xticks(df_without_10.loc[df_without_10.index.values==47]["Date"].values)
    ax.set_title(yvar)
    ax.set_ylabel("")
g.tight_layout()
display()

# %%
c = sns.lineplot(x=np.linspace(10, 100, 1000), y=np.linspace(10, 100, 1000))
c.get_shared_x_axes()

# %%
c.get_shared_x_axes().remove(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 c.get_shared_x_axes().remove(c)
#
# AttributeError: 'GrouperView' object has no attribute 'remove'
