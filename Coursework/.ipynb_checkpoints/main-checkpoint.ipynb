# %% [markdown]
# <h1 align="center"> <b>Курсова робота</b> </h1>
# <h3 align="center"> <em><b>Аналіз даних за допомогою Python та бібліотеки Pandas</b></em> </h3>
#
# ---
#
# <p style="text-align:right"><b>Виконав:</b></br>Студент групи ФІ-21, НН ФТІ</p>

# %% [markdown]
# <h2 align="center">Частина №1</h2>
# <p>Мета: Вивчення основних принципів роботи та використання програмних
# компонентів Anaconda. Інсталяція. Дослідження можливостей IPython Notebook.</p>
# <h3 align="center">Вступ</h3>
# <p>Ipython Notebook — це середовище розробки, що дає можливості для
# інтерактивної та ітеративної розробки проектів, пов’язаних з Data Science.
# Notebook інтегрує код та результати його виконання в один файл разом з
# графіками, текстом, математичними виразами та іншими можливими видами
# представлення інформації.</br></br>
# JupyterLab - це новітнє інтерактивне веб-середовище для розробки блокнотів, коду та даних. Його гнучкий інтерфейс дозволяє користувачам налаштовувати та організовувати робочі процеси в науці про дані, наукових обчисленнях, комп'ютерній журналістиці та машинному навчанні. Модульна конструкція дозволяє розширювати та збагачувати функціональність.</br></br>
# Блокнот (notebook) представляє код і результат його виведення в єдиному документі, який об’єднує візуалізацію, розмічений текст, математичні рівняння та інші мультимедійні дані. Цей інтуїтивно зрозумілий робочий процес сприяє ітеративній і швидкій розробці, що робить ноутбуки все більш популярним вибором для подання даних і їх аналізу. Notebook інтегрує код та результати його виконання в один файл разом з графіками, текстом, математичними виразами та іншими можливими видами представлення інформації.</p>
# <h3 align="center">Підготовка до роботи</h3>
# <ol>
#     <li>Для початку варто завантажити <a href="https://www.anaconda.com/download">Anaconda Distribution</a></li>
#     <li>Після завантаження запускаємо <b>Anaconda Poweshell Prompt</b></li>
#     <li>За допомогою команди <code>cd Папка1\папка2</code> вибираємо необхідну директорію, а командою <code>[потрібний диск]:</code> змніюємо диск</li>
#     <li>Далі створюємо віртуальне середовище командою <code>conda --prefix=[Назва вірутального середовища] python=3.11.5</code></li>
#     <li><code>conda activate</code> - активуємо середовище</li>
#     <li>Інсталюємо JupyterLab <code>conda install jupyterlab</code></li>
#     <li>Командою <code>jupyter lab</code> запускаємо JupyterLab</li>
# </ol>
# <h3 align="center">Можливості Jupyter Notebook</h3>
# <ul>
#     <li>Редагувати Python код в браузері, з підсвічуванням синтаксису, автовідступами і автодоповненням</li>
#     <li>Запускати код в браузері</li>
#     <li>Відображати результати обчислень з медіа представленням(схеми, графіки)</li>
#     <li>Працювати з мовою розмітки Markdown і LaTeX</li>
# </ul>

# %% [markdown]
# Приклад роботи з LaTeX
# $$\frac{1}{\sigma\sqrt{2\pi}}\exp\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)$$

# %% [markdown]
# <h2 align="center">Частина №2</h2>
# <p>Мета: Отримати досвід використання основних засобів аналізу та візуалізації даних у середовищі IPython Notebook на модельних наборах даних.</br></br>
# В роботі використовується публічний набір даних <a href="https://www.kaggle.com/datasets/neuromusic/avocado-prices"><em><b>Avocado Prices</b></em></a>.</p>

# %% [markdown]
# >Імпортуємо необхідні бібліотеки

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math

print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# > Відкриваємо dataset та виводимо перших 5 рядків

# %%
df = pd.read_csv("dataset/avocado.csv", index_col="Unnamed: 0")
df = df.sort_values(by=['Date'])
df.head()
# Out:
#           Date  AveragePrice  Total Volume     4046      4225     4770  \
# 51  2015-01-04          1.75      27365.89  9307.34   3844.81   615.28
# 51  2015-01-04          1.49      17723.17  1189.35  15628.27     0.00
# 51  2015-01-04          1.68       2896.72   161.68    206.96     0.00
# 51  2015-01-04          1.52      54956.80  3013.04  35456.88  1561.70
# 51  2015-01-04          1.64       1505.12     1.27   1129.50     0.00
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 51    13598.46    13061.10      537.36          0.0       organic  2015
# 51      905.55      905.55        0.00          0.0       organic  2015
# 51     2528.08     2528.08        0.00          0.0       organic  2015
# 51    14925.18    11264.80     3660.38          0.0  conventional  2015
# 51      374.35      186.67      187.68          0.0       organic  2015
#
#                 region
# 51           Southeast
# 51             Chicago
# 51  HarrisburgScranton
# 51          Pittsburgh
# 51               Boise

# %% [markdown]
# > Перевіряємо на наявність порожніх значень

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# > Представлення набору даних у матричному вигляді. Відображення 10 елементів для 4-ох ознак Виділення зеленим кольором максимальні елементи в таблиці, а червоним мінімальні для цих 10-ти елементів.

# %%
df_matrix_foramt = df.pivot(columns=["region", "type"], index="Date", values="AveragePrice").head(10).sort_values(by=["region"], axis=1)
df_matrix_foramt.style.highlight_max(axis=0, props="background-color:green").\
format('{:.2f}').\
highlight_min(axis=0, props="background-color:red").\
set_table_styles([{'selector': 'th.col_heading', 'props': 'text-align: center;'}], overwrite=False)
# Out:
# <style type="text/css">
# #T_f32e3 th.col_heading {
#   text-align: center;
# }
# #T_f32e3_row0_col8, #T_f32e3_row0_col17, #T_f32e3_row0_col20, #T_f32e3_row0_col28, #T_f32e3_row0_col35, #T_f32e3_row0_col39, #T_f32e3_row0_col42, #T_f32e3_row0_col43, #T_f32e3_row0_col46, #T_f32e3_row0_col56, #T_f32e3_row0_col59, #T_f32e3_row0_col66, #T_f32e3_row0_col87, #T_f32e3_row0_col94, #T_f32e3_row1_col12, #T_f32e3_row1_col45, #T_f32e3_row1_col65, #T_f32e3_row1_col82, #T_f32e3_row1_col83, #T_f32e3_row2_col55, #T_f32e3_row2_col69, #T_f32e3_row2_col81, #T_f32e3_row2_col91, #T_f32e3_row2_col104, #T_f32e3_row4_col1, #T_f32e3_row4_col3, #T_f32e3_row4_col4, #T_f32e3_row4_col5, #T_f32e3_row4_col6, #T_f32e3_row4_col11, #T_f32e3_row4_col15, #T_f32e3_row4_col16, #T_f32e3_row4_col18, #T_f32e3_row4_col21, #T_f32e3_row4_col22, #T_f32e3_row4_col24, #T_f32e3_row4_col26, #T_f32e3_
">
#   <thead>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th id="T_f32e3_level0_col0" class="col_heading level0 col0" colspan="2">Albany</th>
#       <th id="T_f32e3_level0_col2" class="col_heading level0 col2" colspan="2">Atlanta</th>
#       <th id="T_f32e3_level0_col4" class="col_heading level0 col4" colspan="2">BaltimoreWashington</th>
#       <th id="T_f32e3_level0_col6" class="col_heading level0 col6" colspan="2">Boise</th>
#       <th id="T_f32e3_level0_col8" class="col_heading level0 col8" colspan="2">Boston</th>
#       <th id="T_f32e3_level0_col10" class="col_heading level0 col10" colspan="2">BuffaloRochester</th>
#       <th id="T_f32e3_level0_col12" class="col_heading level0 col12" colspan="2">California</th>
#       <th id="T_f32e3_level0_col14" class="col_heading level0 col14" colspan="2">Charlotte</th>
#       <th id="T_f32e3_level0_col16" class="col_heading level0 col16" colspan="2">Chicago</th>
#       <th id="T_f32e3_level0_col18" class="col_heading level0 col18" colspan="2">CincinnatiDayton</th>
#       <th id="T_f32e3_level0_col20" class="col_heading level0 col20" colspan="2">Columbus</th>
#       <th id="T_f32e3_level0_col22" class="col_heading level0 col22" colspan="2">DallasFtWorth</th>
#       <th id="T_f32e3_level0_col24" class="col_heading level0 col24" colspan="2">Denver</th>
#       <th id="T_f32e3_level0_col26" class="col_heading level0 col26" colspan="2">Detroit</th>
#       <th id="T_f32e3_level0_col28" class="col_heading level0 col28" colspan="2">GrandRapids</th>
#       <th id="T_f32e3_level0_col30" class="col_heading level0 col30" colspan="2">GreatLakes</th>
#       <th id="T_f32e3_level0_col32" class="col_heading level0 col32" colspan="2">HarrisburgScranton</th>
#       <th id="T_f32e3_level0_col34" class="col_heading level0 col34" colspan="2">HartfordSpringfield</th>
#       <th id="T_f32e3_level0_col36" class="col_heading level0 col36" colspan="2">Houston</th>
#       <th id="T_f32e3_level0_col38" class="col_heading level0 col38" colspan="2">Indianapolis</th>
#       <th id="T_f32e3_level0_col40" class="col_heading level0 col40" colspan="2">Jacksonville</th>
#       <th id="T_f32e3_level0_col42" class="col_heading level0 col42" colspan="2">LasVegas</th>
#       <th id="T_f32e3_level0_col44" class="col_heading level0 col44" colspan="2">LosAngeles</th>
#       <th id="T_f32e3_level0_col46" class="col_heading level0 col46" colspan="2">Louisville</th>
#       <th id="T_f32e3_level0_col48" class="col_heading level0 col48" colspan="2">MiamiFtLauderdale</th>
#       <th id="T_f32e3_level0_col50" class="col_heading level0 col50" colspan="2">Midsouth</th>
#       <th id="T_f32e3_level0_col52" class="col_heading level0 col52" colspan="2">Nashville</th>
#       <th id="T_f32e3_level0_col54" class="col_heading level0 col54" colspan="2">NewOrleansMobile</th>
#       <th id="T_f32e3_level0_col56" class="col_heading level0 col56" colsp

# %% [markdown]
# > Математичне сподівання та дисперсія

# %%
X_ = lambda x: x.sum()/len(x)
disp = lambda x: math.sqrt(sum(x**2)/len(x) - X_(x)**2)
print("Порівння обчисленого матемитичного сподівання за допомгою функції Pandas та формулою:", abs(X_(df["AveragePrice"])-df["AveragePrice"].mean()))
print("Порівння обчисленої дисперсії за допомгою функції Pandas та формулою:", abs(disp(df["AveragePrice"])-df["AveragePrice"].std()))
# Out:
# Порівння обчисленого матемитичного сподівання за допомгою функції Pandas та формулою: 0.0
# Порівння обчисленої дисперсії за допомгою функції Pandas та формулою: 1.1032990029635759e-05

# %% [markdown]
# > Стандартизування даних

# %%
def standartization(df):
    dataframe = df.copy()
    
    df_for_stand_org = dataframe[dataframe["type"]=="organic"].select_dtypes(include='float64')
    df_for_stand_org  = ( df_for_stand_org - df_for_stand_org.mean() )/ df_for_stand_org.std()
    
    df_for_stand_conv = dataframe[dataframe["type"]=="conventional"].select_dtypes(include='float64')
    df_for_stand_conv  = ( df_for_stand_conv - df_for_stand_conv.mean() )/ df_for_stand_conv.std()
    
    standartization_df = dataframe
    
    standartization_df.loc[standartization_df["type"]=="organic", list(df_for_stand_org.columns)] = df_for_stand_org
    standartization_df.loc[standartization_df["type"]=="conventional", list(df_for_stand_org.columns)] = df_for_stand_conv
    return standartization_df


standartization(df[df["region"]=="TotalUS"])
# Out:
#           Date  AveragePrice  Total Volume      4046      4225      4770  \
# 51  2015-01-04     -0.815603     -0.394038  0.140141  0.850200 -0.173310
# 51  2015-01-04     -0.424313     -1.172483  1.595150 -1.187734 -0.265342
# 50  2015-01-11     -0.621586     -0.985303  2.303270 -0.612993 -0.403453
# 50  2015-01-11     -0.471011     -0.763554 -0.188716  0.220000 -0.121089
# 49  2015-01-18     -0.621586     -0.841192  1.990425  0.045691 -0.354799
# ..         ...           ...           ...       ...       ...       ...
# 2   2018-03-11     -0.011554      1.097493  0.841265 -0.362563 -0.490414
# 1   2018-03-18     -0.029766      2.341421  0.420903  1.770658 -1.115006
# 1   2018-03-18     -0.241283      1.250598  0.686744 -0.234344 -0.634891
# 0   2018-03-25      0.019552      1.958467 -0.514858  0.447878 -1.108654
# 0   2018-03-25     -0.356147      1.581342  0.858150  0.216166 -0.371432
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 51   -1.488867   -1.545307   -1.191652    -1.019055  conventional  2015
# 51   -1.241281   -1.058389   -1.129569    -0.344028       organic  2015
# 50   -1.330357   -1.094194   -1.311193    -0.344028       organic  2015
# 50   -1.483014   -1.455734   -1.371772    -1.046200  conventional  2015
# 49   -1.297391   -1.115937   -1.156335    -0.344028       organic  2015
# ..         ...         ...         ...          ...           ...   ...
# 2     1.810295    1.987787    1.189334     1.370344  conventional  2018
# 1     1.980740    2.086131    0.806406     2.214936       organic  2018
# 1     2.152272    2.132585    1.962947     1.361635  conventional  2018
# 0     2.106790    2.370955    0.477257     1.828062       organic  2018
# 0     2.286204    2.507059    1.510768     1.718248  conventional  2018
#
#      region
# 51  TotalUS
# 51  TotalUS
# 50  TotalUS
# 50  TotalUS
# 49  TotalUS
# ..      ...
# 2   TotalUS
# 1   TotalUS
# 1   TotalUS
# 0   TotalUS
# 0   TotalUS
#
# [338 rows x 13 columns]

# %% [markdown]
# > Візуалізація даних

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 20))

sns.lineplot(
    ax = axes[0, 0], data = standartization(df[df["region"]=="TotalUS"]),
    x = "AveragePrice", y = "Total Volume", hue = "type",
    marker = "o"
)
axes[0, 0].set_title("(Lineplot) Графік відношення середньої ціни за авокадо до загальної кількості проданих авокад")

sns.barplot(
    ax = axes[0, 1], data = df[df["region"].isin(list(df["region"].head()))], x = "region", y = "Total Volume",
    hue = "type"
)
axes[0, 1].set_title("(Barplot) ")

sns.heatmap(
    ax = axes[1, 0], data = df.loc[(df["type"]=="organic")&(df["region"].isin(list(set(list(df["region"])))[:10]))&(df["Date"].isin(list(set(list(df["Date"])))[:10]))].pivot(index="region", columns="Date", values="AveragePrice")
)
axes[1, 0].set_title("(Heatmap) ")

sns.histplot(
    ax = axes[1, 1], data = df
)
axes[1, 1].set_title("(Histplot) ")
# Out:
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\ProgramFile\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df[["year", "region", "AveragePrice"]]
display( df.loc[(df["type"]=="organic")&(df["region"].isin(list(set(list(df["region"])))[:10]))&(df["Date"].isin(list(set(list(df["Date"])))[:10]))].pivot(index="region", columns="Date", values="AveragePrice") )
#list(set(list(df["region"])))[:10]
# Out:
# Date                2015-03-29  2015-07-05  2015-07-12  2015-08-02  \
# region
# Boston                    1.98        2.13        2.19        2.12
# California                1.53        1.67        1.80        1.99
# HarrisburgScranton        1.79        2.01        1.92        1.96
# Houston                   1.24        1.17        1.17        1.17
# Jacksonville              1.76        1.87        1.91        2.21
# LasVegas                  1.43        1.60        2.09        1.80
# RichmondNorfolk           1.60        1.49        1.28        1.70
# Sacramento                1.64        1.86        1.72        2.10
# SouthCarolina             1.93        1.84        1.84        1.94
# Spokane                   1.55        1.85        2.07        2.11
#
# Date                2016-06-05  2016-08-14  2017-05-14  2017-07-02  \
# region
# Boston                    1.49        1.23        1.99        2.13
# California                1.55        1.47        1.76        1.73
# HarrisburgScranton        1.59        1.62        2.13        2.15
# Houston                   1.05        1.10        1.39        1.21
# Jacksonville              1.64        2.10        2.22        2.25
# LasVegas                  1.41        2.14        1.89        1.73
# RichmondNorfolk           0.95        1.43        1.72        1.84
# Sacramento                2.08        1.96        2.43        2.32
# SouthCarolina             1.31        1.61        1.91        1.82
# Spokane                   1.91        2.25        1.56        2.56
#
# Date                2017-08-06  2017-12-10
# region
# Boston                    1.61        1.74
# California                2.18        1.89
# HarrisburgScranton        1.63        1.41
# Houston                   1.40        1.51
# Jacksonville              2.09        1.59
# LasVegas                  1.74        1.68
# RichmondNorfolk           1.66        1.40
# Sacramento                1.99        1.75
# SouthCarolina             1.74        1.42
# Spokane                   2.45        2.06

# %%
sns.heatmap(
    data = df.loc[(df["type"]=="organic")&(df["region"].isin(list(set(list(df["region"])))[:10]))&(df["Date"].isin(list(set(list(df["Date"])))[:10]))].pivot(index="region", columns="Date", values="AveragePrice")
)

# %%
df.head()
